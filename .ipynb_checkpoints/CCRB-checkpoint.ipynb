# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Import CSV

# %%
alleg = pd.read_csv('/Users/Kevin/gitbasics/introDA/INTRO-TO-DATA-ANALYSIS/NYC_Police/CCRB-Complaint-Data/allegations.csv')

# %%
alleg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33358 entries, 0 to 33357
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   unique_mos_id             33358 non-null  int64
#  1   first_name                33358 non-null  object
#  2   last_name                 33358 non-null  object
#  3   command_now               33358 non-null  object
#  4   complaint_id              33358 non-null  int64
#  5   month_received            33358 non-null  int64
#  6   year_received             33358 non-null  int64
#  7   month_closed              33358 non-null  int64
#  8   year_closed               33358 non-null  int64
#  9   command_at_incident       31814 non-null  object
#  10  rank_abbrev_incident      33358 non-null  object
#  11  rank_abbrev_now           33358 non-null  object
#  12  rank_now                  33358 non-null  object
#  13  rank_incident             33358 non-null  object
#  14  mos_ethnicity             33358 non-null  object
#  15  mos_gender                33358 non-null  object
#  16  mos_age_incident          33358 non-null  int64
#  17  complainant_ethnicity     28894 non-null  object
#  18  complainant_gender        29163 non-null  object
#  19  complainant_age_incident  28546 non-null  float64
#  20  fado_type                 33358 non-null  object
#  21  allegation                33357 non-null  object
#  22  precinct                  33358 non-null  int32
#  23  contact_reason            33159 non-null  object
#  24  outcome_description       33302 non-null  object
#  25  board_disposition         33358 non-null  object
#  26  borough                   33358 non-null  object
# dtypes: float64(1), int32(1), int64(7), object(18)
# memory usage: 6.7+ MB

# %%
alleg.head()
# Out:
#    unique_mos_id first_name last_name command_now  complaint_id  \
# 0          10004   Jonathan      Ruiz     078 PCT         42835
# 1          10007       John     Sears     078 PCT         24601
# 2          10007       John     Sears     078 PCT         24601
# 3          10007       John     Sears     078 PCT         26146
# 4          10009      Noemi    Sierra     078 PCT         40253
#
#    month_received  year_received  month_closed  year_closed  \
# 0               7           2019             5         2020
# 1              11           2011             8         2012
# 2              11           2011             8         2012
# 3               7           2012             9         2013
# 4               8           2018             2         2019
#
#   command_at_incident  ... mos_age_incident complainant_ethnicity  \
# 0             078 PCT  ...               32                 Black
# 1                PBBS  ...               24                 Black
# 2                PBBS  ...               24                 Black
# 3                PBBS  ...               25                 Black
# 4             078 PCT  ...               39                   NaN
#
#   complainant_gender complainant_age_incident           fado_type  \
# 0             Female                     38.0  Abuse of Authority
# 1               Male                     26.0         Discourtesy
# 2               Male                     26.0  Offensive Language
# 3               Male                     45.0  Abuse of Authority
# 4                NaN                     16.0               Force
#
#                      allegation  precinct  \
# 0  Failure to provide RTKA card      78.0
# 1                        Action      67.0
# 2                          Race      67.0
# 3                      Question      67.0
# 4                Physical force      67.0
#
#                                  contact_reason  \
# 0                       Report-domestic dispute
# 1                              Moving violation
# 2                              Moving violation
# 3  PD suspected C/V of violation/crime - street
# 4                                Report-dispute
#
#                 outcome_description                         board_disposition
# 0  No arrest made or summons issued  Substantiated (Command Lvl Instructions)
# 1   Moving violation summons issued                   Substantiated (Charges)
# 2   Moving violation summons issued                   Substantiated (Charges)
# 3  No arrest made or summons issued                   Substantiated (Charges)
# 4    Arrest - other violation/crime      Substantiated (Command Discipline A)
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Cleaning Data

# %%
list(alleg['precinct'].unique())
# Out:
# [78,
#  67,
#  79,
#  77,
#  81,
#  73,
#  90,
#  75,
#  120,
#  10,
#  25,
#  110,
#  83,
#  46,
#  9,
#  28,
#  1,
#  68,
#  70,
#  72,
#  122,
#  113,
#  101,
#  100,
#  7,
#  13,
#  71,
#  23,
#  112,
#  69,
#  32,
#  94,
#  63,
#  76,
#  52,
#  47,
#  62,
#  42,
#  84,
#  115,
#  109,
#  5,
#  88,
#  14,
#  103,
#  107,
#  104,
#  40,
#  108,
#  50,
#  45,
#  18,
#  102,
#  114,
#  19,
#  20,
#  106,
#  105,
#  17,
#  60,
#  34,
#  44,
#  48,
#  41,
#  43,
#  111,
#  49,
#  26,
#  30,
#  33,
#  6,
#  61,
#  123,
#  121,
#  66,
#  24,
#  0,
#  22,
#  1000]

# %%
list(alleg['rank_incident'].unique())
# Out:
# ['Police Officer',
#  'Sergeant',
#  'Detective',
#  'Lieutenant',
#  'Captain',
#  'Deputy Inspector',
#  'Inspector',
#  'Chiefs and other ranks']

# %%
list(alleg['rank_abbrev_incident'].unique())
# Out:
# ['POM',
#  'POF',
#  'SGT',
#  'DT3',
#  'LT',
#  'PO',
#  'CPT',
#  'DTS',
#  'SSA',
#  'LSA',
#  'DT2',
#  'DT1',
#  'DI',
#  'INS',
#  'DC',
#  'SDS',
#  'DET',
#  'LCD']

# %%
alleg.precinct = alleg.precinct.fillna(0)

# %%
## Changing Precinct from int to str

alleg.precinct = alleg.precinct.astype(np.int)

# %% [markdown]
# ## Add Boroughs for Precincts

# %%
# Precincts = [alleg['precinct'] <= 39,
#              (alleg['precinct'] >= 40) & (alleg['precinct'] <= 59),
#              (alleg['precinct'] >= 60) & (alleg['precinct'] <= 99), 
#              (alleg['precinct'] >= 100) & (alleg['precinct'] <= 119),
# #              (alleg['precinct'] >= 120)]
# test_column = ['Manhattan', 'Bronx', 'Brooklyn','Queens', 'Staten Island']
# alleg['borough'] = np.select(Precincts, test_column)

Borough = []
for i in alleg['precinct']:
    if i <= 39 :
        Borough.append('Manhattan')
    elif i >= 40 and i <= 59:
        Borough.append('Bronx')
    elif i >= 60 and i <= 99:
        Borough.append('Brooklyn')
    elif i >= 100 and i < 119:
        Borough.append('Queens')
    else:
        Borough.append('Staten Island')
        
        
        
Borough = pd.Series(Borough)
alleg['borough'] = Borough

# %% [markdown]
# ## Reassign Ranks to Numbers

# %%
Rank = []
for i in alleg['rank_abbrev_now']:
    if i == 'POM' :
        Rank.append(1)
    elif i == 'POF':
        Rank.append(1)
    elif  i == 'PO':
        Rank.append(1)
    elif i == 'DT1':
        Rank.append(2)
    elif i == 'DT2':
        Rank.append(3)
    elif i == 'DT3':
        Rank.append(4)
    elif i == 'DET':
        Rank.append(4)
    elif i == 'DTS':
        Rank.append(4.5)
    elif i == 'SGT':
        Rank.append(5)
    elif i == 'SDS':
        Rank.append(5.5)
    elif i == 'LCD':
        Rank.append(5.9)
    elif i == 'LT':
        Rank.append(6)
    elif i == 'LSA':
        Rank.append(6.5)
    elif i == 'CPT':
        Rank.append(7)
    elif i == 'DI':
        Rank.append(8)
    elif i == 'INS':
        Rank.append(9)
    else:
        Rank.append(10)
        
        
        
Rank = pd.Series(Rank)
alleg['rank_num_now'] = Rank

# %%
Rank_in = []
for i in alleg['rank_abbrev_incident']:
    if i == 'POM' :
        Rank_in.append(1)
    elif i == 'POF':
        Rank_in.append(1)
    elif  i == 'PO':
        Rank_in.append(1)
    elif i == 'DT1':
        Rank_in.append(2)
    elif i == 'DT2':
        Rank_in.append(3)
    elif i == 'DT3':
        Rank_in.append(4)
    elif i == 'DET':
        Rank_in.append(4)
    elif i == 'DTS':
        Rank_in.append(4.5)
    elif i == 'SGT':
        Rank_in.append(5)
    elif i == 'SDS':
        Rank_in.append(5.5)
    elif i == 'LCD':
        Rank_in.append(5.9)
    elif i == 'LT':
        Rank_in.append(6)
    elif i == 'LSA':
        Rank_in.append(6.5)
    elif i == 'CPT':
        Rank_in.append(7)
    elif i == 'DI':
        Rank_in.append(8)
    elif i == 'INS':
        Rank_in.append(9)
    else:
        Rank_in.append(10)
        
        
        
Rank_in = pd.Series(Rank_in)
alleg['rank_num_incedent'] = Rank_in

# %%
# Out:
#      unique_mos_id first_name last_name command_now  complaint_id  \
# 0            10004   Jonathan      Ruiz     078 PCT         42835
# 1            10007       John     Sears     078 PCT         24601
# 2            10007       John     Sears     078 PCT         24601
# 3            10007       John     Sears     078 PCT         26146
# 4            10009      Noemi    Sierra     078 PCT         40253
# ..             ...        ...       ...         ...           ...
# 395          10265     Kieran     Tracy     079 PCT         30811
# 396          10265     Kieran     Tracy     079 PCT         30811
# 397          10265     Kieran     Tracy     079 PCT         39875
# 398          10266     Philip       Tse     079 PCT         37651
# 399          10275      Kevan  Williams     079 PCT         33623
#
#      month_received  year_received  month_closed  year_closed  \
# 0                 7           2019             5         2020
# 1                11           2011             8         2012
# 2                11           2011             8         2012
# 3                 7           2012             9         2013
# 4                 8           2018             2         2019
# ..              ...            ...           ...          ...
# 395               6           2014             3         2015
# 396               6           2014             3         2015
# 397               7           2018             6         2019
# 398               7           2017            12         2017
# 399              10           2015             1         2016
#
#     command_at_incident  ... complainant_age_incident           fado_type  \
# 0               078 PCT  ...                     38.0  Abuse of Authority
# 1                  PBBS  ...                     26.0         Discourtesy
# 2                  PBBS  ...                     26.0  Offensive Language
# 3                  PBBS  ...                     45.0  Abuse of Authority
# 4               078 PCT  ...                     16.0               Force
# ..                  ...  ...                      ...                 ...
# 395             112 PCT  ...                     26.0  Abuse of Authority
# 396             112 PCT  ...                     26.0  Abuse of Authority
# 397             079 PCT  ...                     53.0  Abuse of Authority
# 398             079 PCT  ...                     42.0  Abuse of Authority
# 399             079 PCT  ...                     65.0  Abuse of Authority
#
#                                 allegation precinct  \
# 0             Failure to provide RTKA card       78
# 1                                   Action       67
# 2                                     Race       67
# 3                                 Question       67
# 4                           Physical force       67
# ..                                     ...      ...
# 395                     Search (of person)      112
# 396                     Search (of person)      112
# 397                         Strip-searched       79
# 398  Refusal to process civilian complaint       79
# 399  Refusal to provide name/shield number       79
#
#                                    contact_reason  \
# 0                         Report-domestic dispute
# 1                                Moving violation
# 2                                Moving violation
# 3    PD suspected C/V of violation/crime - street
# 4                                  Report-dispute
# ..                                            ...
# 395  PD suspected C/V of violation/crime - street
# 396  PD suspected C/V of violation/crime - street
# 397           Report-possession/sale of narcotics
# 398                   Execution of search warrant
# 399    PD suspected C/V of violation/crime - bldg
#
#                   outcome_description  \
# 0    No arrest made or summons issued
# 1     Moving violation summons issued
# 2     Moving violation summons issued
# 3    No arrest made or summons issued
# 4      Arrest - other violation/crime
# ..                                ...
# 395  No arrest made or summons issued
# 396  No arrest made or summons issued
# 397    Arrest - other violation/crime
# 398  No arrest made or summons issued
# 399    Arrest - other violation/crime
#
#                             board_disposition   borough rank_num  \
# 0    Substantiated (Command Lvl Instructions)  Brooklyn      1.0
# 1                     Substantiated (Charges)  Brooklyn      1.0
# 2                     Substantiated (Charges)  Brooklyn      1.0
# 3                     Substantiated (Charges)  Brooklyn      1.0
# 4        Substantiated (Command Discipline A)  Brooklyn      1.0
# ..                                        ...       ...      ...
# 395                           Unsubstantiated    Queens      5.0
# 396      Substantiated (Command Discipline A)    Queens      5.0
# 397                           Unsubstantiated  Brooklyn      5.0
# 398  Substantiated (Command Lvl Instructions)  Brooklyn      1.0
# 399                           Unsubstantiated  Brooklyn      1.0
#
#      rank_num_incedent
# 0                  1.0
# 1                  1.0
# 2                  1.0
# 3                  1.0
# 4                  1.0
# ..                 ...
# 395                1.0
# 396                1.0
# 397                5.0
# 398                1.0
# 399                1.0
#
# [400 rows x 29 columns]

# %%
list(alleg.borough.unique())
# Out:
# ['Brooklyn', 'Staten Island', 'Manhattan', 'Queens', 'Bronx']

# %%
alleg.groupby(['borough']).count()['allegation']
# Out:
# borough
# Bronx             8329
# Brooklyn         12754
# Manhattan         6035
# Queens            4676
# Staten Island     1563
# Name: allegation, dtype: int64

# %%
alleg.head()
# Out:
#    unique_mos_id first_name last_name command_now  complaint_id  \
# 0          10004   Jonathan      Ruiz     078 PCT         42835
# 1          10007       John     Sears     078 PCT         24601
# 2          10007       John     Sears     078 PCT         24601
# 3          10007       John     Sears     078 PCT         26146
# 4          10009      Noemi    Sierra     078 PCT         40253
#
#    month_received  year_received  month_closed  year_closed  \
# 0               7           2019             5         2020
# 1              11           2011             8         2012
# 2              11           2011             8         2012
# 3               7           2012             9         2013
# 4               8           2018             2         2019
#
#   command_at_incident  ... complainant_ethnicity complainant_gender  \
# 0             078 PCT  ...                 Black             Female
# 1                PBBS  ...                 Black               Male
# 2                PBBS  ...                 Black               Male
# 3                PBBS  ...                 Black               Male
# 4             078 PCT  ...                   NaN                NaN
#
#   complainant_age_incident           fado_type                    allegation  \
# 0                     38.0  Abuse of Authority  Failure to provide RTKA card
# 1                     26.0         Discourtesy                        Action
# 2                     26.0  Offensive Language                          Race
# 3                     45.0  Abuse of Authority                      Question
# 4                     16.0               Force                Physical force
#
#   precinct                                contact_reason  \
# 0       78                       Report-domestic dispute
# 1       67                              Moving violation
# 2       67                              Moving violation
# 3       67  PD suspected C/V of violation/crime - street
# 4       67                                Report-dispute
#
#                 outcome_description                         board_disposition  \
# 0  No arrest made or summons issued  Substantiated (Command Lvl Instructions)
# 1   Moving violation summons issued                   Substantiated (Charges)
# 2   Moving violation summons issued                   Substantiated (Charges)
# 3  No arrest made or summons issued                   Substantiated (Charges)
# 4    Arrest - other violation/crime      Substantiated (Command Discipline A)
#
#     borough
# 0  Brooklyn
# 1  Brooklyn
# 2  Brooklyn
# 3  Brooklyn
# 4  Brooklyn
#
# [5 rows x 27 columns]

# %%
alleg.groupby(['rank_abbrev_now', 'mos_age_incident']).aggregate(np.mean)['complaint_id'].round()
# Out:
# rank_abbrev_now  mos_age_incident
# AC               21                    973.0
#                  23                   1721.0
#                  24                   1881.0
#                  26                   1334.0
#                  27                   2388.0
#                                       ...
# SSA              48                  39774.0
#                  49                  34910.0
#                  50                  34003.0
#                  51                  40133.0
#                  55                  28794.0
# Name: complaint_id, Length: 542, dtype: float64

# %%
alleg.to_excel(r'/Users/Kevin/gitbasics/introDA/INTRO-TO-DATA-ANALYSIS/NYC_Police/Update2.xlsx')
