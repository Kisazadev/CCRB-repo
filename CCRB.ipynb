# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Import CSV

# %%
alleg = pd.read_csv('/Users/Kevin/gitbasics/introDA/INTRO-TO-DATA-ANALYSIS/NYC_Police/CCRB-Complaint-Data/allegations.csv')
test1 = pd.read_csv('/Users/Kevin/gitbasics/introDA/INTRO-TO-DATA-ANALYSIS/NYC_Police/Update2.csv')
# Out:
# C:\Users\Kevin\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (10) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
alleg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33358 entries, 0 to 33357
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   unique_mos_id             33358 non-null  int64
#  1   first_name                33358 non-null  object
#  2   last_name                 33358 non-null  object
#  3   command_now               33358 non-null  object
#  4   complaint_id              33358 non-null  int64
#  5   month_received            33358 non-null  int64
#  6   year_received             33358 non-null  int64
#  7   month_closed              33358 non-null  int64
#  8   year_closed               33358 non-null  int64
#  9   command_at_incident       31814 non-null  object
#  10  rank_abbrev_incident      33358 non-null  object
#  11  rank_abbrev_now           33358 non-null  object
#  12  rank_now                  33358 non-null  object
#  13  rank_incident             33358 non-null  object
#  14  mos_ethnicity             33358 non-null  object
#  15  mos_gender                33358 non-null  object
#  16  mos_age_incident          33358 non-null  int64
#  17  complainant_ethnicity     28894 non-null  object
#  18  complainant_gender        29163 non-null  object
#  19  complainant_age_incident  28546 non-null  float64
#  20  fado_type                 33358 non-null  object
#  21  allegation                33357 non-null  object
#  22  precinct                  33334 non-null  float64
#  23  contact_reason            33159 non-null  object
#  24  outcome_description       33302 non-null  object
#  25  board_disposition         33358 non-null  object
# dtypes: float64(2), int64(7), object(17)
# memory usage: 6.6+ MB

# %%
alleg.head()
# Out:
#    unique_mos_id first_name last_name command_now  complaint_id  \
# 0          10004   Jonathan      Ruiz     078 PCT         42835
# 1          10007       John     Sears     078 PCT         24601
# 2          10007       John     Sears     078 PCT         24601
# 3          10007       John     Sears     078 PCT         26146
# 4          10009      Noemi    Sierra     078 PCT         40253
#
#    month_received  year_received  month_closed  year_closed  \
# 0               7           2019             5         2020
# 1              11           2011             8         2012
# 2              11           2011             8         2012
# 3               7           2012             9         2013
# 4               8           2018             2         2019
#
#   command_at_incident  ... mos_age_incident complainant_ethnicity  \
# 0             078 PCT  ...               32                 Black
# 1                PBBS  ...               24                 Black
# 2                PBBS  ...               24                 Black
# 3                PBBS  ...               25                 Black
# 4             078 PCT  ...               39                   NaN
#
#   complainant_gender complainant_age_incident           fado_type  \
# 0             Female                     38.0  Abuse of Authority
# 1               Male                     26.0         Discourtesy
# 2               Male                     26.0  Offensive Language
# 3               Male                     45.0  Abuse of Authority
# 4                NaN                     16.0               Force
#
#                      allegation  precinct  \
# 0  Failure to provide RTKA card      78.0
# 1                        Action      67.0
# 2                          Race      67.0
# 3                      Question      67.0
# 4                Physical force      67.0
#
#                                  contact_reason  \
# 0                       Report-domestic dispute
# 1                              Moving violation
# 2                              Moving violation
# 3  PD suspected C/V of violation/crime - street
# 4                                Report-dispute
#
#                 outcome_description                         board_disposition
# 0  No arrest made or summons issued  Substantiated (Command Lvl Instructions)
# 1   Moving violation summons issued                   Substantiated (Charges)
# 2   Moving violation summons issued                   Substantiated (Charges)
# 3  No arrest made or summons issued                   Substantiated (Charges)
# 4    Arrest - other violation/crime      Substantiated (Command Discipline A)
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Cleaning Data

# %%
# alleg['unique_mos_id'].unique()
alleg['unique_mos_id'].nunique()
# Out:
# 3996

# %%
list(alleg['rank_abbrev_incident'].unique())
# Out:
# ['POM',
#  'POF',
#  'SGT',
#  'DT3',
#  'LT',
#  'PO',
#  'CPT',
#  'DTS',
#  'SSA',
#  'LSA',
#  'DT2',
#  'DT1',
#  'DI',
#  'INS',
#  'DC',
#  'SDS',
#  'DET',
#  'LCD']

# %%
alleg.precinct = alleg.precinct.fillna(0)

# %%
## Changing Precinct from int to str

alleg.precinct = alleg.precinct.astype(np.int)

# %% [markdown]
# ## Add Boroughs for Precincts

# %%
# Precincts = [alleg['precinct'] <= 39,
#              (alleg['precinct'] >= 40) & (alleg['precinct'] <= 59),
#              (alleg['precinct'] >= 60) & (alleg['precinct'] <= 99), 
#              (alleg['precinct'] >= 100) & (alleg['precinct'] <= 119),
# #              (alleg['precinct'] >= 120)]
# test_column = ['Manhattan', 'Bronx', 'Brooklyn','Queens', 'Staten Island']
# alleg['borough'] = np.select(Precincts, test_column)

Borough = []
for i in alleg['precinct']:
    if i <= 39 :
        Borough.append('Manhattan')
    elif i >= 40 and i <= 59:
        Borough.append('Bronx')
    elif i >= 60 and i <= 99:
        Borough.append('Brooklyn')
    elif i >= 100 and i < 119:
        Borough.append('Queens')
    else:
        Borough.append('Staten Island')
        
        
        
Borough = pd.Series(Borough)
alleg['borough'] = Borough

# %% [markdown]
# ## Reassign Ranks to Numbers

# %%
Rank = []
for i in alleg['rank_abbrev_now']:
    if i == 'POM' :
        Rank.append(1)
    elif i == 'POF':
        Rank.append(1)
    elif  i == 'PO':
        Rank.append(1)
    elif i == 'DT1':
        Rank.append(2)
    elif i == 'DT2':
        Rank.append(3)
    elif i == 'DT3':
        Rank.append(4)
    elif i == 'DET':
        Rank.append(4)
    elif i == 'DTS':
        Rank.append(4.5)
    elif i == 'SGT':
        Rank.append(5)
    elif i == 'SDS':
        Rank.append(5.5)
    elif i == 'LCD':
        Rank.append(5.9)
    elif i == 'LT':
        Rank.append(6)
    elif i == 'LSA':
        Rank.append(6.5)
    elif i == 'CPT':
        Rank.append(7)
    elif i == 'DI':
        Rank.append(8)
    elif i == 'INS':
        Rank.append(9)
    else:
        Rank.append(10)
        
        
        
Rank = pd.Series(Rank)
alleg['rank_num_now'] = Rank

# %%
Rank_in = []
for i in alleg['rank_abbrev_incident']:
    if i == 'POM' :
        Rank_in.append(1)
    elif i == 'POF':
        Rank_in.append(1)
    elif  i == 'PO':
        Rank_in.append(1)
    elif i == 'DT1':
        Rank_in.append(2)
    elif i == 'DT2':
        Rank_in.append(3)
    elif i == 'DT3':
        Rank_in.append(4)
    elif i == 'DET':
        Rank_in.append(4)
    elif i == 'DTS':
        Rank_in.append(4.5)
    elif i == 'SGT':
        Rank_in.append(5)
    elif i == 'SDS':
        Rank_in.append(5.5)
    elif i == 'LCD':
        Rank_in.append(5.9)
    elif i == 'LT':
        Rank_in.append(6)
    elif i == 'LSA':
        Rank_in.append(6.5)
    elif i == 'CPT':
        Rank_in.append(7)
    elif i == 'DI':
        Rank_in.append(8)
    elif i == 'INS':
        Rank_in.append(9)
    else:
        Rank_in.append(10)
        
        
        
Rank_in = pd.Series(Rank_in)
alleg['rank_num_incedent'] = Rank_in

# %%
alleg.rank_num_now = alleg.rank_num_now.astype(np.int)
alleg.rank_num_incedent = alleg.rank_num_incedent.astype(np.int)

# %%
alleg.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33358 entries, 0 to 33357
# Data columns (total 29 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   unique_mos_id             33358 non-null  int64
#  1   first_name                33358 non-null  object
#  2   last_name                 33358 non-null  object
#  3   command_now               33358 non-null  object
#  4   complaint_id              33358 non-null  int64
#  5   month_received            33358 non-null  int64
#  6   year_received             33358 non-null  int64
#  7   month_closed              33358 non-null  int64
#  8   year_closed               33358 non-null  int64
#  9   command_at_incident       31814 non-null  object
#  10  rank_abbrev_incident      33358 non-null  object
#  11  rank_abbrev_now           33358 non-null  object
#  12  rank_now                  33358 non-null  object
#  13  rank_incident             33358 non-null  object
#  14  mos_ethnicity             33358 non-null  object
#  15  mos_gender                33358 non-null  object
#  16  mos_age_incident          33358 non-null  int64
#  17  complainant_ethnicity     28894 non-null  object
#  18  complainant_gender        29163 non-null  object
#  19  complainant_age_incident  28546 non-null  float64
#  20  fado_type                 33358 non-null  object
#  21  allegation                33357 non-null  object
#  22  precinct                  33358 non-null  int32
#  23  contact_reason            33159 non-null  object
#  24  outcome_description       33302 non-null  object
#  25  board_disposition         33358 non-null  object
#  26  borough                   33358 non-null  object
#  27  rank_num_now              33358 non-null  int32
#  28  rank_num_incedent         33358 non-null  int32
# dtypes: float64(1), int32(3), int64(7), object(18)
# memory usage: 7.0+ MB

# %% [markdown]
# ## Were officers promoted after a substantiated case?

# %%
Promotion = []
for i in alleg['rank_abbrev_incident']:
    if (alleg.loc[alleg['board_disposition'].str.contains('Substantiated'), 'rank_num_now']) > (alleg.rank_num_incedent):
        Promotion.append(True)
    else:
        Promotion.append(False)

# Also does not work
# for i in alleg['rank_abbrev_incident']:
#     if i in alleg.loc[alleg['board_disposition'].str.contains('Substantiated'), 'rank_num_now'] > alleg.loc[alleg['board_disposition'].str.contains('Substantiated'), 'rank_num_incedent']:
#         Promotion.append('Yes')
#     else:
#         Promotion.append('No')
        
Promotion = pd.Series(Promotion)
alleg['Promotions'] = Promotion
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-f1edd4c5a7a0> in <module>
#       1 Promotion = []
#       2 for i in alleg['rank_abbrev_incident']:
# ----> 3     if (alleg.loc[alleg['board_disposition'].str.contains('Substantiated'), 'rank_num_now']) > (alleg.rank_num_incedent):
#       4         Promotion.append(True)
#       5     else:
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other)
#     519
#     520         if isinstance(other, ABCSeries) and not self._indexed_same(other):
# --> 521             raise ValueError("Can only compare identically-labeled Series objects")
#     522
#     523         lvalues = extract_array(self, extract_numpy=True)
#
# ValueError: Can only compare identically-labeled Series objects

# %%
alleg['Promotions'] = np.where(alleg.loc[alleg['board_disposition'].str.contains('Substantiated'), 'rank_num_now']) > alleg['rank_num_incedent']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-7aeebc8433bf> in <module>
# ----> 1 alleg['Promotions'] = np.where(alleg.loc[alleg['board_disposition'].str.contains('Substantiated'), 'rank_num_now']) > alleg['rank_num_incedent']
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\common.py in new_method(self, other)
#      62         other = item_from_zerodim(other)
#      63
# ---> 64         return method(self, other)
#      65
#      66     return new_method
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\__init__.py in wrapper(self, other)
#     524         rvalues = extract_array(other, extract_numpy=True)
#     525
# --> 526         res_values = comparison_op(lvalues, rvalues, op)
#     527
#     528         return _construct_result(self, res_values, index=self.index, name=res_name)
#
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in comparison_op(left, right, op)
#     251         method = getattr(lvalues, op_name)
#     252         with np.errstate(all="ignore"):
# --> 253             res_values = method(rvalues)
#     254
#     255         if res_values is NotImplemented:
#
# ValueError: operands could not be broadcast together with shapes (33358,) (1,8301)

# %% [markdown]
# ### This one finally worked

# %%
test1.loc[test1['board_disposition'].str.contains("Substantiated \ (", 'Promotions')]
# Out:
#        Unnamed: 0  unique_mos_id first_name  last_name command_now  \
# 202         26122          35937     Robert     Graves     WARRSEC
# 203         25757          35832     Damion      Brown     WARRSEC
# 204         25860          35869     Carlos   Corporan     WARRSEC
# 205         25861          35869     Carlos   Corporan     WARRSEC
# 206         25971          35893    Starlin  Dominguez     WARRSEC
# ...           ...            ...        ...        ...         ...
# 33347       30249            687     Andrew     Beirne     009 PCT
# 33351       29012            559   Ausencio  Fernandez     007 PCT
# 33352       29013            559   Ausencio  Fernandez     007 PCT
# 33353        9968            200    Rodrigo  Caballero     005 DET
# 33356       27588             43      Lynda   Chervoni     001 PCT
#
#        complaint_id  month_received  year_received  month_closed  year_closed  \
# 202           27832               4           2013             9         2014
# 203           37264               5           2017             7         2018
# 204           38548              12           2017             7         2018
# 205           38548              12           2017             7         2018
# 206           40930              11           2018            12         2019
# ...             ...             ...            ...           ...          ...
# 33347          3078               1           1998             1         1998
# 33351          2501               8           1996             8         1996
# 33352          2501               8           1996             8         1996
# 33353          4055              12           1999             7         2000
# 33356          5855              10           2002             8         2003
#
#        ...           fado_type                             allegation  \
# 202    ...  Abuse of Authority       Premises entered and/or searched
# 203    ...  Abuse of Authority       Premises entered and/or searched
# 204    ...  Abuse of Authority                      Entry of Premises
# 205    ...  Abuse of Authority                     Search of Premises
# 206    ...  Abuse of Authority                      Entry of Premises
# ...    ...                 ...                                    ...
# 33347  ...               Force                                   Mace
# 33351  ...  Abuse of Authority                        Threat of force
# 33352  ...               Force                                   Beat
# 33353  ...               Force                                Vehicle
# 33356  ...  Abuse of Authority  Refusal to provide name/shield number
#
#       precinct                              contact_reason  \
# 202          9  PD suspected C/V of violation/crime - bldg
# 203         32                 Execution of search warrant
# 204        121           Execution of arrest/bench warrant
# 205        121           Execution of arrest/bench warrant
# 206         40  PD suspected C/V of violation/crime - bldg
# ...        ...                                         ...
# 33347       17                          Arrest/Complainant
# 33351        7                            Patrol Encounter
# 33352        7                            Patrol Encounter
# 33353        1                                       Other
# 33356      120                              Report-dispute
#
#                     outcome_description                    board_disposition  \
# 202      Arrest - other violation/crime         Substantiated (Instructions)
# 203    No arrest made or summons issued  Substantiated (Formalized Training)
# 204    No arrest made or summons issued  Substantiated (Formalized Training)
# 205    No arrest made or summons issued  Substantiated (Formalized Training)
# 206    No arrest made or summons issued  Substantiated (Formalized Training)
# ...                                 ...                                  ...
# 33347    Disorderly-Conduct/Arr/Summons   Substantiated (Command Discipline)
# 33351    Disorderly-Conduct/Arr/Summons   Substantiated (Command Discipline)
# 33352    Disorderly-Conduct/Arr/Summons   Substantiated (Command Discipline)
# 33353  No arrest made or summons issued              Substantiated (Charges)
# 33356  No arrest made or summons issued              Substantiated (Charges)
#
#              borough  rank_num_now rank_num_incedent Promotions
# 202        Manhattan             3                 4         No
# 203        Manhattan             5                 5         No
# 204    Staten Island             4                 4         No
# 205    Staten Island             4                 4         No
# 206            Bronx             4                 1        Yes
# ...              ...           ...               ...        ...
# 33347      Manhattan             1                 1         No
# 33351      Manhattan             1                 1         No
# 33352      Manhattan             1                 1         No
# 33353      Manhattan             3                 2        Yes
# 33356  Staten Island             5                 1        Yes
#
# [8301 rows x 31 columns]

# %%
alleg.head()
# Out:
#    unique_mos_id first_name last_name command_now  complaint_id  \
# 0          10004   Jonathan      Ruiz     078 PCT         42835
# 1          10007       John     Sears     078 PCT         24601
# 2          10007       John     Sears     078 PCT         24601
# 3          10007       John     Sears     078 PCT         26146
# 4          10009      Noemi    Sierra     078 PCT         40253
#
#    month_received  year_received  month_closed  year_closed  \
# 0               7           2019             5         2020
# 1              11           2011             8         2012
# 2              11           2011             8         2012
# 3               7           2012             9         2013
# 4               8           2018             2         2019
#
#   command_at_incident  ...           fado_type                    allegation  \
# 0             078 PCT  ...  Abuse of Authority  Failure to provide RTKA card
# 1                PBBS  ...         Discourtesy                        Action
# 2                PBBS  ...  Offensive Language                          Race
# 3                PBBS  ...  Abuse of Authority                      Question
# 4             078 PCT  ...               Force                Physical force
#
#   precinct                                contact_reason  \
# 0       78                       Report-domestic dispute
# 1       67                              Moving violation
# 2       67                              Moving violation
# 3       67  PD suspected C/V of violation/crime - street
# 4       67                                Report-dispute
#
#                 outcome_description                         board_disposition  \
# 0  No arrest made or summons issued  Substantiated (Command Lvl Instructions)
# 1   Moving violation summons issued                   Substantiated (Charges)
# 2   Moving violation summons issued                   Substantiated (Charges)
# 3  No arrest made or summons issued                   Substantiated (Charges)
# 4    Arrest - other violation/crime      Substantiated (Command Discipline A)
#
#     borough rank_num_now rank_num_incedent  Promotions
# 0  Brooklyn            1                 1        True
# 1  Brooklyn            1                 1        True
# 2  Brooklyn            1                 1        True
# 3  Brooklyn            1                 1        True
# 4  Brooklyn            1                 1        True
#
# [5 rows x 30 columns]

# %%
alleg.to_excel(r'/Users/Kevin/gitbasics/introDA/INTRO-TO-DATA-ANALYSIS/NYC_Police/Update2.xlsx')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\xlsxwriter\workbook.py in close(self)
#     315             try:
# --> 316                 self._store_workbook()
#     317             except IOError as e:
#
# ~\anaconda3\lib\site-packages\xlsxwriter\workbook.py in _store_workbook(self)
#     631         except IOError as e:
# --> 632             raise e
#     633
#
# ~\anaconda3\lib\site-packages\xlsxwriter\workbook.py in _store_workbook(self)
#     629             xlsx_file = ZipFile(self.filename, "w", compression=ZIP_DEFLATED,
# --> 630                                 allowZip64=self.allow_zip64)
#     631         except IOError as e:
#
# ~\anaconda3\lib\zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel)
#    1239                 try:
# -> 1240                     self.fp = io.open(file, filemode)
#    1241                 except OSError:
#
# PermissionError: [Errno 13] Permission denied: '/Users/Kevin/gitbasics/introDA/INTRO-TO-DATA-ANALYSIS/NYC_Police/Update2.xlsx'
#
# During handling of the above exception, another exception occurred:
#
# FileCreateError                           Traceback (most recent call last)
# <ipython-input-33-411565940090> in <module>
# ----> 1 alleg.to_excel(r'/Users/Kevin/gitbasics/introDA/INTRO-TO-DATA-ANALYSIS/NYC_Police/Update2.xlsx')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    2179             startcol=startcol,
#    2180             freeze_panes=freeze_panes,
# -> 2181             engine=engine,
#    2182         )
#    2183
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\excel.py in write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine)
#     736         )
#     737         if need_save:
# --> 738             writer.save()
#
# ~\anaconda3\lib\site-packages\pandas\io\excel\_xlsxwriter.py in save(self)
#     193         """
#     194
# --> 195         return self.book.close()
#     196
#     197     def write_cells(
#
# ~\anaconda3\lib\site-packages\xlsxwriter\workbook.py in close(self)
#     316                 self._store_workbook()
#     317             except IOError as e:
# --> 318                 raise FileCreateError(e)
#     319             except LargeZipFile as e:
#     320                 raise FileSizeError("Filesize would require ZIP64 extensions. "
#
# FileCreateError: [Errno 13] Permission denied: '/Users/Kevin/gitbasics/introDA/INTRO-TO-DATA-ANALYSIS/NYC_Police/Update2.xlsx'

# %%
alleg.loc[alleg['board_disposition'].str.contains('Substantiated'), 'rank_num_now'])
